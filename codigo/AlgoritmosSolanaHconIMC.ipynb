# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sea
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import xgboost as xgb
import tensorflow as tf

# %%
df = pd.read_csv('SolAtasIMC_tratado.csv')

# %% [markdown]
# Imprimimos la información general de los datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36400 entries, 0 to 36399
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    36400 non-null  object
#  1   open    36400 non-null  float64
#  2   high    36400 non-null  float64
#  3   low     36400 non-null  float64
#  4   close   36400 non-null  float64
#  5   value   36400 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
tamanio = df.shape[0]

# %% [markdown]
# Creamos los conjuntos de entrenamiento, validación y test

# %%
df_train = df.copy().loc[0:int(tamanio*0.7)]
df_train
# Out:
#                       date   open   high    low  close  value
# 0      2020-08-12 03:00:00   3.10   3.35   3.10   3.25     75
# 1      2020-08-12 04:00:00   3.25   3.25   3.15   3.15     75
# 2      2020-08-12 05:00:00   3.15   3.30   3.15   3.30     75
# 3      2020-08-12 06:00:00   3.30   3.30   3.15   3.30     75
# 4      2020-08-12 07:00:00   3.25   3.25   3.20   3.25     75
# ...                    ...    ...    ...    ...    ...    ...
# 25476  2023-07-11 21:00:00  22.00  22.05  21.90  22.00     57
# 25477  2023-07-11 22:00:00  22.00  22.10  21.90  22.00     57
# 25478  2023-07-11 23:00:00  22.00  22.05  21.75  21.95     57
# 25479  2023-07-12 00:00:00  21.95  22.10  21.90  22.05     64
# 25480  2023-07-12 01:00:00  22.05  22.15  22.00  22.10     64
#
# [25481 rows x 6 columns]

# %%
df_vali = df.copy().loc[int(tamanio*0.7 + 1):int(tamanio*0.9)]
df_vali
# Out:
#                       date    open    high     low   close  value
# 25481  2023-07-12 02:00:00   22.10   22.30   22.05   22.15     64
# 25482  2023-07-12 03:00:00   22.15   22.25   22.10   22.10     64
# 25483  2023-07-12 04:00:00   22.10   22.10   22.00   22.00     64
# 25484  2023-07-12 05:00:00   22.00   22.00   21.90   21.95     64
# 25485  2023-07-12 06:00:00   21.95   22.05   21.90   22.00     64
# ...                    ...     ...     ...     ...     ...    ...
# 32756  2024-05-10 05:00:00  153.65  154.35  152.85  153.95     66
# 32757  2024-05-10 06:00:00  153.95  154.70  153.45  153.75     66
# 32758  2024-05-10 07:00:00  153.75  154.10  152.30  153.30     66
# 32759  2024-05-10 08:00:00  153.30  155.10  153.15  154.95     66
# 32760  2024-05-10 09:00:00  154.95  155.75  154.25  154.35     66
#
# [7280 rows x 6 columns]

# %%
df_test = df.copy().loc[int(tamanio*0.9 + 1):tamanio]
df_test
# Out:
#                       date    open   high     low   close  value
# 32761  2024-05-10 10:00:00  154.35  154.5  153.45  154.10     66
# 32762  2024-05-10 11:00:00  154.10  154.8  153.25  154.15     66
# 32763  2024-05-10 12:00:00  154.15  154.3  153.25  154.15     66
# 32764  2024-05-10 13:00:00  154.15  155.2  153.00  155.05     66
# 32765  2024-05-10 14:00:00  155.05  155.4  153.10  153.30     66
# ...                    ...     ...    ...     ...     ...    ...
# 36395  2024-10-08 20:00:00  143.35  143.9  142.35  142.95     49
# 36396  2024-10-08 21:00:00  142.95  144.1  142.25  143.75     49
# 36397  2024-10-08 22:00:00  143.75  144.5  143.35  144.50     49
# 36398  2024-10-08 23:00:00  144.50  144.7  144.05  144.25     49
# 36399  2024-10-09 00:00:00  144.25  144.3  143.55  143.80     49
#
# [3639 rows x 6 columns]

# %% [markdown]
# Declaramos el modelo RandomForestRegressor

# %%
regr1 = RandomForestRegressor(max_depth=100, random_state=0)

# %% [markdown]
# Preparamos los datos en el formato necesario para entrenar el algoritmo

# %%
X1 = []
y1= []
for i in range(0, df_train.shape[0] - 1):
    auxy = df_train.iloc[i + 1]
    y1.append(auxy.close)
    aux = df_train.iloc[i]
    aux1 = []
    for r in range(1, aux.size):
        aux1.append(aux[r])
    X1.append(aux1)
# Out:
# C:\Users\raulg\AppData\Local\Temp\ipykernel_20108\2244255699.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   aux1.append(aux[r])

# %% [markdown]
# Entrenamos el algoritmo

# %%
regr1.fit(X1, y1)
# Out:
# RandomForestRegressor(max_depth=100, random_state=0)

# %% [markdown]
# Probamos el algoritmo con los datos de validación

# %%
Vali1 = []
aux = df_vali.iloc[0]
for r in range (0,df_vali.shape[0] - 1):
    aux = df_vali.iloc[r]
    Vali1aux = []
    for i in range(1, aux.size):
        Vali1aux.append(aux[i])
    Vali1.append(Vali1aux)
predict = regr1.predict(Vali1)
print(predict)
# Out:
# C:\Users\raulg\AppData\Local\Temp\ipykernel_20108\3274649085.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Vali1aux.append(aux[i])
# [ 22.1805  22.116   22.0085 ... 153.837  153.1125 155.9625]

# %%
Valirpr = []
for i in range(1,df_vali.shape[0]):
    Valirpr.append(df_vali.iloc[i].close)

# %% [markdown]
# Comparamos gráficamente la predicción y el precio real

# %%
plt.plot(Valirpr, color='blue', label='Precio real')  # Línea azul
plt.plot(predict, color='red', label='Predicción')   # Línea roja
plt.title('Gráfico comparación predicción/precio real')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend() 

plt.show()

# %% [markdown]
# Calculamos el error medio(mae) y el error porcentual medio(emp)

# %%
suma = 0
n = len(Valirpr)
mae = np.mean(np.abs(Valirpr - predict))
print("El error medio absoluto es: " + str(mae))
for i in range(0,n):
    suma = abs(predict[i] - Valirpr[i])/Valirpr[i] +  suma
error_medio = suma/n
emp = error_medio*100 # error medio en porcentaje
print("El error medio porcentualemente es: " + str(emp))
# Out:
# El error medio absoluto es: 0.8113275540694354
# El error medio porcentualemente es: 0.9670508918721916

# %% [markdown]
# Probamos el algoritmo con los datos de test

# %%
Test1 = []
aux = df_test.iloc[0]
for r in range (0,df_test.shape[0] - 1):
    aux = df_test.iloc[r]
    Test1aux = []
    for i in range(1, aux.size):
        Test1aux.append(aux[i])
    Test1.append(Test1aux)
predictT = regr1.predict(Test1)
print(predictT)
# Out:
# C:\Users\raulg\AppData\Local\Temp\ipykernel_20108\886282011.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Test1aux.append(aux[i])
# [154.31   153.732  154.3395 ... 142.393  142.6115 142.779 ]

# %%
Testrpr = []
for i in range(1,df_test.shape[0]):
    Testrpr.append(df_test.iloc[i].close)

# %% [markdown]
# Comparamos gráficamente la predicción y el precio real

# %%
plt.plot(Testrpr, color='blue', label='Precio real')  # Línea azul
plt.plot(predictT, color='red', label='Predicción')   # Línea roja
plt.title('Gráfico comparación predicción/precio real')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend() 

plt.show()

# %% [markdown]
# Calculamos el error medio(mae) y el error porcentual medio(emp)

# %%
suma = 0
n = len(Testrpr)
mae = np.mean(np.abs(Testrpr - predictT))
print("El error medio absoluto es: " + str(mae))
for i in range(0,n):
    suma = abs(predictT[i] - Testrpr[i])/Testrpr[i] +  suma
error_medio = suma/n
emp = error_medio*100 # error medio en porcentaje
print("El error medio porcentualemente es: " + str(emp))
# Out:
# El error medio absoluto es: 1.1719781473336992
# El error medio porcentualemente es: 0.7826227595698083

# %% [markdown]
# # Predicción Utilizando XGBoost

# %%
df_xgb = df.copy()
df_xgb['close_next'] = df_xgb['close'].shift(-1)

# %%
df_xgb = df_xgb.dropna()
df_xgb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36399 entries, 0 to 36398
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        36399 non-null  object
#  1   open        36399 non-null  float64
#  2   high        36399 non-null  float64
#  3   low         36399 non-null  float64
#  4   close       36399 non-null  float64
#  5   value       36399 non-null  int64
#  6   close_next  36399 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
tamanio_xgb = df_xgb.shape[0]
tamanio_xgb
# Out:
# 36399

# %%
df_train_xgb = df_xgb.copy().loc[0:int(tamanio_xgb*0.7)]
df_train_xgb
# Out:
#                       date   open   high    low  close  value  close_next
# 0      2020-08-12 03:00:00   3.10   3.35   3.10   3.25     75        3.15
# 1      2020-08-12 04:00:00   3.25   3.25   3.15   3.15     75        3.30
# 2      2020-08-12 05:00:00   3.15   3.30   3.15   3.30     75        3.30
# 3      2020-08-12 06:00:00   3.30   3.30   3.15   3.30     75        3.25
# 4      2020-08-12 07:00:00   3.25   3.25   3.20   3.25     75        3.25
# ...                    ...    ...    ...    ...    ...    ...         ...
# 25475  2023-07-11 20:00:00  22.10  22.10  21.95  22.00     57       22.00
# 25476  2023-07-11 21:00:00  22.00  22.05  21.90  22.00     57       22.00
# 25477  2023-07-11 22:00:00  22.00  22.10  21.90  22.00     57       21.95
# 25478  2023-07-11 23:00:00  22.00  22.05  21.75  21.95     57       22.05
# 25479  2023-07-12 00:00:00  21.95  22.10  21.90  22.05     64       22.10
#
# [25480 rows x 7 columns]

# %%
df_vali_xgb = df_xgb.copy().loc[int(tamanio_xgb*0.7 + 1):int(tamanio_xgb*0.9)]
df_vali_xgb
# Out:
#                       date    open    high     low   close  value  close_next
# 25480  2023-07-12 01:00:00   22.05   22.15   22.00   22.10     64       22.15
# 25481  2023-07-12 02:00:00   22.10   22.30   22.05   22.15     64       22.10
# 25482  2023-07-12 03:00:00   22.15   22.25   22.10   22.10     64       22.00
# 25483  2023-07-12 04:00:00   22.10   22.10   22.00   22.00     64       21.95
# 25484  2023-07-12 05:00:00   22.00   22.00   21.90   21.95     64       22.00
# ...                    ...     ...     ...     ...     ...    ...         ...
# 32755  2024-05-10 04:00:00  153.40  153.80  152.70  153.65     66      153.95
# 32756  2024-05-10 05:00:00  153.65  154.35  152.85  153.95     66      153.75
# 32757  2024-05-10 06:00:00  153.95  154.70  153.45  153.75     66      153.30
# 32758  2024-05-10 07:00:00  153.75  154.10  152.30  153.30     66      154.95
# 32759  2024-05-10 08:00:00  153.30  155.10  153.15  154.95     66      154.35
#
# [7280 rows x 7 columns]

# %%
df_test_xgb = df_xgb.copy().loc[int(tamanio_xgb*0.9 + 1):tamanio_xgb]
df_test_xgb
# Out:
#                       date    open    high     low   close  value  close_next
# 32760  2024-05-10 09:00:00  154.95  155.75  154.25  154.35     66      154.10
# 32761  2024-05-10 10:00:00  154.35  154.50  153.45  154.10     66      154.15
# 32762  2024-05-10 11:00:00  154.10  154.80  153.25  154.15     66      154.15
# 32763  2024-05-10 12:00:00  154.15  154.30  153.25  154.15     66      155.05
# 32764  2024-05-10 13:00:00  154.15  155.20  153.00  155.05     66      153.30
# ...                    ...     ...     ...     ...     ...    ...         ...
# 36394  2024-10-08 19:00:00  143.80  143.95  142.40  143.35     49      142.95
# 36395  2024-10-08 20:00:00  143.35  143.90  142.35  142.95     49      143.75
# 36396  2024-10-08 21:00:00  142.95  144.10  142.25  143.75     49      144.50
# 36397  2024-10-08 22:00:00  143.75  144.50  143.35  144.50     49      144.25
# 36398  2024-10-08 23:00:00  144.50  144.70  144.05  144.25     49      143.80
#
# [3639 rows x 7 columns]

# %% [markdown]
# Definimos los datos y características del entrenamiento

# %%
X = df_train_xgb[['open', 'high', 'low', 'close']] 
y = df_train_xgb['close_next']
X1 = df_vali_xgb[['open', 'high', 'low', 'close']] 
y1 = df_vali_xgb['close_next']

# %%
dtrain = xgb.DMatrix(data=X, label=y)
dvali = xgb.DMatrix(data=X1, label=y1)

# %%
param = {'max_depth': 10, 'eta': 0.1, 'objective': 'reg:squarederror'}
evals = [(dtrain, 'train'), (dvali, 'validacion')]

# %% [markdown]
# Entrenamos el modelo XGBoost

# %%
bst = xgb.train(param, dtrain, num_boost_round=1000, evals=evals, early_stopping_rounds=10, verbose_eval=10)
# Out:
# [0]	train-rmse:52.03058	validacion-rmse:55.14741
# [10]	train-rmse:18.24075	validacion-rmse:19.29663
# [20]	train-rmse:6.47113	validacion-rmse:6.89713
# [30]	train-rmse:2.49259	validacion-rmse:2.78981
# [40]	train-rmse:1.33772	validacion-rmse:1.70668
# [50]	train-rmse:1.09531	validacion-rmse:1.52521
# [60]	train-rmse:1.05078	validacion-rmse:1.50811
# [70]	train-rmse:1.03892	validacion-rmse:1.50938

# %% [markdown]
# Lo probamos con los datos de validación

# %%
predict_xgb = bst.predict(dvali)

# %%
Valirpr_xgb = []
for i in range(0,df_vali_xgb.shape[0]):
    Valirpr_xgb.append(df_vali_xgb.iloc[i].close)

# %%
plt.plot(Valirpr_xgb, color='blue', label='Precio real')  # Línea azul
plt.plot(predict_xgb, color='red', label='Predicción')   # Línea roja
plt.title('Gráfico comparación predicción/precio real')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend() 

plt.show()

# %%
suma = 0
n = len(Valirpr_xgb)
mae = np.mean(np.abs(Valirpr_xgb - predict_xgb))
print("El error medio absoluto es: " + str(mae))
for i in range(0,n):
    suma = abs(predict_xgb[i] - Valirpr_xgb[i])/Valirpr_xgb[i] +  suma
error_medio = suma/n
emp = error_medio*100 # error medio en porcentaje
print("El error medio porcentualemente es: " + str(emp))
# Out:
# El error medio absoluto es: 0.5122382410279995
# El error medio porcentualemente es: 0.6814544222019102

# %% [markdown]
# Preparamos los datos de test en el formato necesario

# %%
df_test_xgb_aux = df_test_xgb.iloc[:-1].copy()
X_test = df_test_xgb_aux[['open', 'high', 'low', 'close']] 
y_test = df_test_xgb_aux['close_next']
dtest = xgb.DMatrix(data=X_test, label=y_test)

# %% [markdown]
# Lo probamos con los datos de test

# %%
predict_xgb_test = bst.predict(dtest)

# %%
Test_xgb = []
for i in range(1,df_test_xgb.shape[0]):
    Test_xgb.append(df_test_xgb.iloc[i].close)

# %%
plt.plot(Test_xgb, color='blue', label='Precio real')  # Línea azul
plt.plot(predict_xgb_test, color='red', label='Predicción')   # Línea roja
plt.title('Gráfico comparación predicción/precio real')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend() 

plt.show()

# %%
suma = 0
n = len(Test_xgb)
mae = np.mean(np.abs(Test_xgb - predict_xgb_test))
print("El error medio absoluto es: " + str(mae))
for i in range(0,n):
    suma = abs(predict_xgb_test[i] - Test_xgb[i])/Test_xgb[i] +  suma
error_medio = suma/n
emp = error_medio*100 # error medio en porcentaje
print("El error medio porcentualemente es: " + str(emp))
# Out:
# El error medio absoluto es: 1.0809644047934774
# El error medio porcentualemente es: 0.7275942239749614

# %% [markdown]
# # Entrenamos un modelo de red neuronal

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
def create_sequences(data, n_steps):
    X, y = [], []
    for i in range(len(data) - n_steps):
        X.append(data[i:i+n_steps])
        y.append(data[i+n_steps, 3])  
    return np.array(X), np.array(y)
df_train_aux = df_train[['open', 'high', 'low', 'close', 'value']].values
X_train, y_train= create_sequences(df_train_aux, 7)
X_train
# Out:
# array([[[ 3.1 ,  3.35,  3.1 ,  3.25, 75.  ],
#         [ 3.25,  3.25,  3.15,  3.15, 75.  ],
#         [ 3.15,  3.3 ,  3.15,  3.3 , 75.  ],
#         ...,
#         [ 3.25,  3.25,  3.2 ,  3.25, 75.  ],
#         [ 3.25,  3.3 ,  3.15,  3.25, 75.  ],
#         [ 3.25,  3.4 ,  3.25,  3.4 , 75.  ]],
#
#        [[ 3.25,  3.25,  3.15,  3.15, 75.  ],
#         [ 3.15,  3.3 ,  3.15,  3.3 , 75.  ],
#         [ 3.3 ,  3.3 ,  3.15,  3.3 , 75.  ],
#         ...,
#         [ 3.25,  3.3 ,  3.15,  3.25, 75.  ],
#         [ 3.25,  3.4 ,  3.25,  3.4 , 75.  ],
#         [ 3.35,  3.55,  3.35,  3.45, 75.  ]],
#
#        [[ 3.15,  3.3 ,  3.15,  3.3 , 75.  ],
#         [ 3.3 ,  3.3 ,  3.15,  3.3 , 75.  ],
#         [ 3.25,  3.25,  3.2 ,  3.25, 75.  ],
#         ...,
#         [ 3.25,  3.4 ,  3.25,  3.4 , 75.  ],
#         [ 3.35,  3.55,  3.35,  3.45, 75.  ],
#         [ 3.45,  3.7 ,  3.4 ,  3.7 , 75.  ]],
#
#        ...,
#
#        [[22.1 , 22.4 , 21.95, 22.2 , 57.  ],
#         [22.2 , 22.25, 21.9 , 22.15, 57.  ],
#         [22.15, 22.2 , 21.95, 22.1 , 57.  ],
#         ...,
#         [22.1 , 22.1 , 21.95, 22.  , 57.  ],
#         [22.  , 22.05, 21.9 , 22.  , 57.  ],
#         [22.  , 22.1 , 21.9 , 22.  , 57.  ]],
#
#        [[22.2 , 22.25, 21.9 , 22.15, 57.  ],
#         [22.15, 22.2 , 21.95, 22.1 , 57.  ],
#         [22.1 , 22.2 , 22.  , 22.1 , 57.  ],
#         ...,
#         [22.  , 22.05, 21.9 , 22.  , 57.  ],
#         [22.  , 22.1 , 21.9 , 22.  , 57.  ],
#         [22.  , 22.05, 21.75, 21.95, 57.  ]],
#
#        [[22.15, 22.2 , 21.95, 22.1 , 57.  ],
#         [22.1 , 22.2 , 22.  , 22.1 , 57.  ],
#         [22.1 , 22.1 , 21.95, 22.  , 57.  ],
#         ...,
#         [22.  , 22.1 , 21.9 , 22.  , 57.  ],
#         [22.  , 22.05, 21.75, 21.95, 57.  ],
#         [21.95, 22.1 , 21.9 , 22.05, 64.  ]]])

# %%
df_vali_aux = df_vali[['open', 'high', 'low', 'close', 'value']].values
X_vali, y_vali= create_sequences(df_vali_aux, 7)
X_vali
# Out:
# array([[[ 22.1 ,  22.3 ,  22.05,  22.15,  64.  ],
#         [ 22.15,  22.25,  22.1 ,  22.1 ,  64.  ],
#         [ 22.1 ,  22.1 ,  22.  ,  22.  ,  64.  ],
#         ...,
#         [ 21.95,  22.05,  21.9 ,  22.  ,  64.  ],
#         [ 22.  ,  22.1 ,  22.  ,  22.05,  64.  ],
#         [ 22.  ,  22.2 ,  22.  ,  22.05,  64.  ]],
#
#        [[ 22.15,  22.25,  22.1 ,  22.1 ,  64.  ],
#         [ 22.1 ,  22.1 ,  22.  ,  22.  ,  64.  ],
#         [ 22.  ,  22.  ,  21.9 ,  21.95,  64.  ],
#         ...,
#         [ 22.  ,  22.1 ,  22.  ,  22.05,  64.  ],
#         [ 22.  ,  22.2 ,  22.  ,  22.05,  64.  ],
#         [ 22.05,  22.15,  22.  ,  22.05,  64.  ]],
#
#        [[ 22.1 ,  22.1 ,  22.  ,  22.  ,  64.  ],
#         [ 22.  ,  22.  ,  21.9 ,  21.95,  64.  ],
#         [ 21.95,  22.05,  21.9 ,  22.  ,  64.  ],
#         ...,
#         [ 22.  ,  22.2 ,  22.  ,  22.05,  64.  ],
#         [ 22.05,  22.15,  22.  ,  22.05,  64.  ],
#         [ 22.05,  22.05,  21.95,  22.05,  64.  ]],
#
#        ...,
#
#        [[150.35, 153.4 , 150.15, 152.95,  66.  ],
#         [152.95, 153.15, 151.2 , 152.6 ,  66.  ],
#         [152.6 , 153.25, 151.35, 152.05,  66.  ],
#         ...,
#         [153.4 , 153.8 , 152.7 , 153.65,  66.  ],
#         [153.65, 154.35, 152.85, 153.95,  66.  ],
#         [153.95, 154.7 , 153.45, 153.75,  66.  ]],
#
#        [[152.95, 153.15, 151.2 , 152.6 ,  66.  ],
#         [152.6 , 153.25, 151.35, 152.05,  66.  ],
#         [152.05, 155.  , 151.45, 153.4 ,  66.  ],
#         ...,
#         [153.65, 154.35, 152.85, 153.95,  66.  ],
#         [153.95, 154.7 , 153.45, 153.75,  66.  ],
#         [153.75, 154.1 , 152.3 , 153.3 ,  66.  ]],
#
#        [[152.6 , 153.25, 151.35, 152.05,  66.  ],
#         [152.05, 155.  , 151.45, 153.4 ,  66.  ],
#         [153.4 , 153.8 , 152.7 , 153.65,  66.  ],
#         ...,
#         [153.95, 154.7 , 153.45, 153.75,  66.  ],
#         [153.75, 154.1 , 152.3 , 153.3 ,  66.  ],
#         [153.3 , 155.1 , 153.15, 154.95,  66.  ]]])

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(35,)))
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mape')
# Out:
# C:\Users\raulg\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
X_trainR = []
for i in X_train:
    aux = []
    for r in range(0, 7):
        for elem in i[r]:
            aux.append(elem)
    X_trainR.append(aux)       
X_trainR = np.array(X_trainR)

# %%
X_valiR = []
for i in X_vali:
    aux = []
    for r in range(0, 7):
        for elem in i[r]:
            aux.append(elem)
    X_valiR.append(aux)  
X_valiR = np.array(X_valiR)

# %%
history = model.fit(X_trainR, y_train, epochs=15, batch_size=96, validation_data=(X_valiR, y_vali), shuffle=False)
# Out:
# Epoch 1/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - loss: 70.5612 - val_loss: 20.9415
# Epoch 2/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 36.3476 - val_loss: 10.7460
# Epoch 3/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 14.7137 - val_loss: 7.1498
# Epoch 4/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 18.9026 - val_loss: 8.6860
# Epoch 5/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 26.9551 - val_loss: 11.5111
# Epoch 6/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 24.1687 - val_loss: 13.5550
# Epoch 7/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 30.3438 - val_loss: 6.6459
# Epoch 8/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 26.2227 - val_loss: 14.9948
# Epoch 9/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 14.7904 - val_loss: 3.7024
# Epoch 10/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 14.2748 - val_loss: 1.9224
# Epoch 11/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step - loss: 18.4136 - val_loss: 2.0146
# Epoch 12/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 12.9799 - val_loss: 1.6354
# Epoch 13/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 10.0453 - val_loss: 2.2454
# Epoch 14/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 8.2626 - val_loss: 1.9327
# Epoch 15/15
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 8.0674 - val_loss: 3.8480

# %%
y_pred = model.predict(X_valiR)
y_pred
# Out:
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step
# array([[ 21.776402],
#        [ 21.772236],
#        [ 21.736065],
#        ...,
#        [145.39366 ],
#        [145.08589 ],
#        [145.4279  ]], dtype=float32)

# %%
Valirpr = []
for i in range(7,df_vali.shape[0]):
    Valirpr.append(df_vali.iloc[i].close)
plt.plot(Valirpr, color='blue', label='Precio real')  # Línea azul
plt.plot(y_pred, color='red', label='Predicción')   # Línea roja
plt.title('Gráfico comparación predicción/precio real')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend() 

plt.show()

# %%
y_pred_aux=[]
for elem in y_pred:
    y_pred_aux.append(elem[0])
y_pred_aux = np.array(y_pred_aux)

# %%
suma = 0
n = len(Valirpr)
mae = np.mean(np.abs(Valirpr - y_pred_aux))
print("El error medio absoluto es: " + str(mae))
for i in range(0,n):
    suma = abs(y_pred_aux[i] - Valirpr[i])/Valirpr[i] +  suma
error_medio = suma/n
emp = error_medio*100 # error medio en porcentaje
print("El error medio porcentualemente es: " + str(emp))
# Out:
# El error medio absoluto es: 3.863159455732484
# El error medio porcentualemente es: 3.84796140759177

# %%
df_test_aux = df_test[['open', 'high', 'low', 'close', 'value']].values
X_test, y_test= create_sequences(df_test_aux, 7)
X_test
# Out:
# array([[[154.35, 154.5 , 153.45, 154.1 ,  66.  ],
#         [154.1 , 154.8 , 153.25, 154.15,  66.  ],
#         [154.15, 154.3 , 153.25, 154.15,  66.  ],
#         ...,
#         [155.05, 155.4 , 153.1 , 153.3 ,  66.  ],
#         [153.3 , 153.7 , 152.45, 153.05,  66.  ],
#         [153.05, 153.25, 145.75, 147.5 ,  66.  ]],
#
#        [[154.1 , 154.8 , 153.25, 154.15,  66.  ],
#         [154.15, 154.3 , 153.25, 154.15,  66.  ],
#         [154.15, 155.2 , 153.  , 155.05,  66.  ],
#         ...,
#         [153.3 , 153.7 , 152.45, 153.05,  66.  ],
#         [153.05, 153.25, 145.75, 147.5 ,  66.  ],
#         [147.5 , 148.65, 145.35, 146.95,  66.  ]],
#
#        [[154.15, 154.3 , 153.25, 154.15,  66.  ],
#         [154.15, 155.2 , 153.  , 155.05,  66.  ],
#         [155.05, 155.4 , 153.1 , 153.3 ,  66.  ],
#         ...,
#         [153.05, 153.25, 145.75, 147.5 ,  66.  ],
#         [147.5 , 148.65, 145.35, 146.95,  66.  ],
#         [146.95, 148.8 , 145.15, 148.  ,  66.  ]],
#
#        ...,
#
#        [[143.3 , 145.1 , 142.7 , 145.05,  49.  ],
#         [145.05, 145.55, 142.45, 144.15,  49.  ],
#         [144.15, 144.4 , 141.2 , 142.8 ,  49.  ],
#         ...,
#         [143.8 , 143.95, 142.4 , 143.35,  49.  ],
#         [143.35, 143.9 , 142.35, 142.95,  49.  ],
#         [142.95, 144.1 , 142.25, 143.75,  49.  ]],
#
#        [[145.05, 145.55, 142.45, 144.15,  49.  ],
#         [144.15, 144.4 , 141.2 , 142.8 ,  49.  ],
#         [142.8 , 143.95, 141.75, 143.8 ,  49.  ],
#         ...,
#         [143.35, 143.9 , 142.35, 142.95,  49.  ],
#         [142.95, 144.1 , 142.25, 143.75,  49.  ],
#         [143.75, 144.5 , 143.35, 144.5 ,  49.  ]],
#
#        [[144.15, 144.4 , 141.2 , 142.8 ,  49.  ],
#         [142.8 , 143.95, 141.75, 143.8 ,  49.  ],
#         [143.8 , 143.95, 142.4 , 143.35,  49.  ],
#         ...,
#         [142.95, 144.1 , 142.25, 143.75,  49.  ],
#         [143.75, 144.5 , 143.35, 144.5 ,  49.  ],
#         [144.5 , 144.7 , 144.05, 144.25,  49.  ]]])

# %%
X_testR = []
for i in X_test:
    aux = []
    for r in range(0, 7):
        for elem in i[r]:
            aux.append(elem)
    X_testR.append(aux)       
X_testR = np.array(X_testR)

# %%
y_predT = model.predict(X_testR)
y_predT
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
# array([[144.51816],
#        [142.92328],
#        [142.57706],
#        ...,
#        [136.59912],
#        [136.45271],
#        [136.65094]], dtype=float32)

# %%
Testrpr = []
for i in range(7,df_test.shape[0]):
    Testrpr.append(df_test.iloc[i].close)
plt.plot(Testrpr, color='blue', label='Precio real')  # Línea azul
plt.plot(y_predT, color='red', label='Predicción')   # Línea roja
plt.title('Gráfico comparación predicción/precio real')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend() 

plt.show()

# %%
y_pred_auxT=[]
for elem in y_predT:
    y_pred_auxT.append(elem[0])
y_pred_auxT = np.array(y_pred_auxT)

# %%
suma = 0
n = len(Testrpr)
mae = np.mean(np.abs(Testrpr - y_pred_auxT))
print("El error medio absoluto es: " + str(mae))
for i in range(0,n):
    suma = abs(y_pred_auxT[i] - Testrpr[i])/Testrpr[i] +  suma
error_medio = suma/n
emp = error_medio*100 # error medio en porcentaje
print("El error medio porcentualemente es: " + str(emp))
# Out:
# El error medio absoluto es: 7.365346418708432
# El error medio porcentualemente es: 4.85291343387606

# %%
#model.save('mi_modelo_densoIMC3_96.h5')

# %%
def eval(Valirpr, y_pred_aux):
    suma = 0
    n = len(Valirpr)
    for i in range(0,n):
        suma = abs(y_pred_aux[i] - Valirpr[i])/Valirpr[i] +  suma
    error_medio = suma/n
    emp = error_medio*100 # error medio en porcentaje
    return emp

# %%
def rpr_prep(df):
    Testrpr = []
    for i in range(7,df.shape[0]):
        Testrpr.append(df.iloc[i].close)
    return Testrpr

# %%
def y_aux_prep(y_predT):
    y_pred_auxT=[]
    for elem in y_predT:
        y_pred_auxT.append(elem[0])
    y_pred_auxT = np.array(y_pred_auxT)
    return y_pred_auxT

# %%
def trainDenso(model, X_trainR, y_train, X_valiR, y_vali, X_testR):
    mejor_valor = 100.0
    epoc_list = [10, 13, 16, 20, 24]
    batch_list = [4, 6, 8, 10, 12, 16, 20, 24, 28, 32, 36, 48, 56, 64, 80, 96, 112, 128, 140, 160, 180, 200, 228, 256]
    for e in epoc_list:
        for b in batch_list:
            for i in range(0, 50):
                history = model.fit(X_trainR, y_train, epochs=e, batch_size=b, validation_data=(X_valiR, y_vali), shuffle=False)
                y_pred = model.predict(X_testR)
                valor = eval(rpr_prep(df_test), y_aux_prep(y_pred))
                if valor < mejor_valor and valor < 0.5878:
                    mejor_valor = valor
                    stri = "modelos_densos\mi_modelo_densoICM" + str(e) + "_" + str(b) + "_" + str(round(valor, 4)) + ".h5"
                    model.save(stri)

# %%
trainDenso(model, X_trainR, y_train, X_valiR, y_vali, X_testR)
# Out:
# Epoch 1/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 586us/step - loss: 4.7914 - val_loss: 5.9059
# Epoch 2/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 582us/step - loss: 4.4550 - val_loss: 5.9890
# Epoch 3/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 583us/step - loss: 4.0579 - val_loss: 5.0740
# Epoch 4/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 579us/step - loss: 3.7450 - val_loss: 4.4814
# Epoch 5/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 579us/step - loss: 3.6157 - val_loss: 4.2938
# Epoch 6/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 582us/step - loss: 3.4879 - val_loss: 4.9925
# Epoch 7/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 585us/step - loss: 3.3183 - val_loss: 4.5088
# Epoch 8/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 583us/step - loss: 3.1996 - val_loss: 3.8985
# Epoch 9/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 590us/step - loss: 3.0852 - val_loss: 4.5185
# Epoch 10/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 590us/step - loss: 3.1480 - val_loss: 5.0167
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 425us/step
# Epoch 1/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s 587us/step - loss: 4.2103 - val_loss: 4.1617
# Epoch 2/10
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 4s

#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py:345, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     334 if getattr(self, "_eval_epoch_iterator", None) is None:
#     335     self._eval_epoch_iterator = TFEpochIterator(
#     336         x=val_x,
#     337         y=val_y,
#    (...)
#     343         shuffle=False,
#     344     )
# --> 345 val_logs = self.evaluate(
#     346     x=val_x,
#     347     y=val_y,
#     348     sample_weight=val_sample_weight,
#     349     batch_size=validation_batch_size or batch_size,
#     350     steps=validation_steps,
#     351     callbacks=callbacks,
#     352     return_dict=True,
#     353     _use_cached_eval_dataset=True,
#     354 )
#     355 val_logs = {
#     356     "val_" + name: val for name, val in val_logs.items()
#     357 }
#     358 epoch_logs.update(val_logs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py:433, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     431 for step, iterator in epoch_iterator.enumerate_epoch():
#     432     callbacks.on_test_batch_begin(step)
# --> 433     logs = self.test_function(iterator)
#     434     logs = self._pythonify_logs(logs)
#     435     callbacks.on_test_batch_end(step, logs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # Entrenamos un modelo LSTM

# %%
from tensorflow.keras.layers import LSTM

# %%
modelLSTM = Sequential()
modelLSTM.add(LSTM(64, activation='relu', input_shape=(7, 5)))
modelLSTM.add(Dense(1))
# Out:
# C:\Users\raulg\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
modelLSTM.compile(optimizer='adam', loss='mape')

# %%
historyLSTM = modelLSTM.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_vali, y_vali), shuffle=False)
# Out:
# Epoch 1/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 11.0310 - val_loss: 5.2498
# Epoch 2/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.2526 - val_loss: 3.6754
# Epoch 3/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.8084 - val_loss: 4.1937
# Epoch 4/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.2715 - val_loss: 5.1996
# Epoch 5/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.0023 - val_loss: 4.7456
# Epoch 6/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.2969 - val_loss: 2.2989
# Epoch 7/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.0531 - val_loss: 5.2862
# Epoch 8/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 15.9256 - val_loss: 5.6532
# Epoch 9/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 13.3434 - val_loss: 6.2539
# Epoch 10/10
# 797/797 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 11.4595 - val_loss: 3.0564

# %%
y_predLSTM = modelLSTM.predict(X_vali)
y_predLSTM
# Out:
# 228/228 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[ 22.167841],
#        [ 22.17166 ],
#        [ 22.149292],
#        ...,
#        [148.19757 ],
#        [147.32751 ],
#        [149.51529 ]], dtype=float32)

# %%
Valirpr = []
for i in range(7,df_vali.shape[0]):
    Valirpr.append(df_vali.iloc[i].close)
plt.plot(Valirpr, color='blue', label='Precio real')  # Línea azul
plt.plot(y_predLSTM, color='red', label='Predicción')   # Línea roja
plt.title('Gráfico comparación predicción/precio real')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend() 

plt.show()

# %%
y_pred_auxLSTM=[]
for elem in y_predLSTM:
    y_pred_auxLSTM.append(elem[0])
y_pred_auxLSTM = np.array(y_pred_auxLSTM)

# %%
suma = 0
n = len(Valirpr)
mae = np.mean(np.abs(Valirpr - y_pred_auxLSTM))
print("El error medio absoluto es: " + str(mae))
for i in range(0,n):
    suma = abs(y_pred_auxLSTM[i] - Valirpr[i])/Valirpr[i] +  suma
error_medio = suma/n
emp = error_medio*100 # error medio en porcentaje
print("El error medio porcentualemente es: " + str(emp))
# Out:
# El error medio absoluto es: 3.0411879671795177
# El error medio porcentualemente es: 3.0564422218392946

# %% [markdown]
# Probamos los datos de test

# %%
df_test_aux = df_test[['open', 'high', 'low', 'close', 'value']].values
X_test, y_test = create_sequences(df_test_aux, 7)
X_test
# Out:
# array([[[154.35, 154.5 , 153.45, 154.1 ,  66.  ],
#         [154.1 , 154.8 , 153.25, 154.15,  66.  ],
#         [154.15, 154.3 , 153.25, 154.15,  66.  ],
#         ...,
#         [155.05, 155.4 , 153.1 , 153.3 ,  66.  ],
#         [153.3 , 153.7 , 152.45, 153.05,  66.  ],
#         [153.05, 153.25, 145.75, 147.5 ,  66.  ]],
#
#        [[154.1 , 154.8 , 153.25, 154.15,  66.  ],
#         [154.15, 154.3 , 153.25, 154.15,  66.  ],
#         [154.15, 155.2 , 153.  , 155.05,  66.  ],
#         ...,
#         [153.3 , 153.7 , 152.45, 153.05,  66.  ],
#         [153.05, 153.25, 145.75, 147.5 ,  66.  ],
#         [147.5 , 148.65, 145.35, 146.95,  66.  ]],
#
#        [[154.15, 154.3 , 153.25, 154.15,  66.  ],
#         [154.15, 155.2 , 153.  , 155.05,  66.  ],
#         [155.05, 155.4 , 153.1 , 153.3 ,  66.  ],
#         ...,
#         [153.05, 153.25, 145.75, 147.5 ,  66.  ],
#         [147.5 , 148.65, 145.35, 146.95,  66.  ],
#         [146.95, 148.8 , 145.15, 148.  ,  66.  ]],
#
#        ...,
#
#        [[143.3 , 145.1 , 142.7 , 145.05,  49.  ],
#         [145.05, 145.55, 142.45, 144.15,  49.  ],
#         [144.15, 144.4 , 141.2 , 142.8 ,  49.  ],
#         ...,
#         [143.8 , 143.95, 142.4 , 143.35,  49.  ],
#         [143.35, 143.9 , 142.35, 142.95,  49.  ],
#         [142.95, 144.1 , 142.25, 143.75,  49.  ]],
#
#        [[145.05, 145.55, 142.45, 144.15,  49.  ],
#         [144.15, 144.4 , 141.2 , 142.8 ,  49.  ],
#         [142.8 , 143.95, 141.75, 143.8 ,  49.  ],
#         ...,
#         [143.35, 143.9 , 142.35, 142.95,  49.  ],
#         [142.95, 144.1 , 142.25, 143.75,  49.  ],
#         [143.75, 144.5 , 143.35, 144.5 ,  49.  ]],
#
#        [[144.15, 144.4 , 141.2 , 142.8 ,  49.  ],
#         [142.8 , 143.95, 141.75, 143.8 ,  49.  ],
#         [143.8 , 143.95, 142.4 , 143.35,  49.  ],
#         ...,
#         [142.95, 144.1 , 142.25, 143.75,  49.  ],
#         [143.75, 144.5 , 143.35, 144.5 ,  49.  ],
#         [144.5 , 144.7 , 144.05, 144.25,  49.  ]]])

# %%
y_predLSTMt = modelLSTM.predict(X_test)
y_predLSTMt
# Out:
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# array([[141.73935],
#        [138.24713],
#        [140.69339],
#        ...,
#        [138.29184],
#        [139.25269],
#        [138.8168 ]], dtype=float32)

# %%
Testrpr = []
for i in range(7,df_test.shape[0]):
    Testrpr.append(df_test.iloc[i].close)
plt.plot(Testrpr, color='blue', label='Precio real')  # Línea azul
plt.plot(y_predLSTMt, color='red', label='Predicción')   # Línea roja
plt.title('Gráfico comparación predicción/precio real')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.legend() 

plt.show()

# %%
y_pred_auxLSTM=[]
for elem in y_predLSTMt:
    y_pred_auxLSTM.append(elem[0])
y_pred_auxLSTM = np.array(y_pred_auxLSTM)

# %%
suma = 0
n = len(Testrpr)
mae = np.mean(np.abs(Testrpr - y_pred_auxLSTM))
print("El error medio absoluto es: " + str(mae))
for i in range(0,n):
    suma = abs(y_pred_auxLSTM[i] - Testrpr[i])/Testrpr[i] +  suma
error_medio = suma/n
emp = error_medio*100 # error medio en porcentaje
print("El error medio porcentualemente es: " + str(emp))
# Out:
# El error medio absoluto es: 5.666565995489448
# El error medio porcentualemente es: 3.7825047684562567

# %%
#modelLSTM.save('mi_modelo_lstmICM10_32.h5')

# %%
def eval(Valirpr, y_pred_aux):
    suma = 0
    n = len(Valirpr)
    for i in range(0,n):
        suma = abs(y_pred_aux[i] - Valirpr[i])/Valirpr[i] +  suma
    error_medio = suma/n
    emp = error_medio*100 # error medio en porcentaje
    return emp

# %%
def rpr_prep(df):
    Testrpr = []
    for i in range(7,df.shape[0]):
        Testrpr.append(df.iloc[i].close)
    return Testrpr

# %%
def y_aux_prep(y_predLSTMt):
    y_pred_auxLSTM=[]
    for elem in y_predLSTMt:
        y_pred_auxLSTM.append(elem[0])
    y_pred_auxLSTM = np.array(y_pred_auxLSTM)
    return y_pred_auxLSTM

# %%
def trainLSTM(modelLSTM, X_train, y_train, X_vali, y_vali, X_test):
    epoc_list = [3, 5, 7, 10, 13, 16, 20, 24]
    batch_list = [4, 6, 8, 10, 12, 16, 20, 24, 28, 32, 36, 48, 56, 64, 80, 96, 112, 128, 140, 160, 180, 200, 228, 256]
    mejor_valor = 100.0
    for e in epoc_list:
        for b in batch_list:
            for i in range(0, 25):
                historyLSTM = modelLSTM.fit(X_train, y_train, epochs=e, batch_size=b, validation_data=(X_vali, y_vali), shuffle=False)
                y_predLSTM = modelLSTM.predict(X_test)
                valor = eval(rpr_prep(df_test), y_aux_prep(y_predLSTM))
                if valor < mejor_valor and valor < 1.0:
                    mejor_valor = valor
                    stri = "modelos_lstm\mi_modelo_lstmICM" + str(e) + "_" + str(b) + "_" + str(round(valor, 4)) + ".h5"
                    modelLSTM.save(stri)

# %%
trainLSTM(modelLSTM, X_train, y_train, X_vali, y_vali, X_test)
# Out:
# Epoch 1/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.2453 - val_loss: 4.9477
# Epoch 2/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.7259 - val_loss: 4.4435
# Epoch 3/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.7099 - val_loss: 3.3490
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# Epoch 1/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.3229 - val_loss: 3.5366
# Epoch 2/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 9s 1ms/step - loss: 2.7426 - val_loss: 3.0821
# Epoch 3/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.8320 - val_loss: 3.0218
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# Epoch 1/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.7206 - val_loss: 2.4756
# Epoch 2/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.6063 - val_loss: 3.0037
# Epoch 3/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.6801 - val_loss: 2.9658
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# Epoch 1/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.9623 - val_loss: 2.8766
# Epoch 2/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.5824 - val_loss: 2.9088
# Epoch 3/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.6450 - val_loss: 2.9134
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# Epoch 1/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.6587 - val_loss: 2.8805
# Epoch 2/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.5767 - val_loss: 2.8232
# Epoch 3/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.5619 - val_loss: 2.7936
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Epoch 1/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.1991 - val_loss: 2.7539
# Epoch 2/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2.1061 - val_loss: 2.7450
# Epoch 3/3
# 6369/6369 ━━━━━━━━━━━━━━━━━━━━ 8s 1ms/step - loss: 2
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Epoch 1/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.7676 - val_loss: 2.4540
# Epoch 2/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.9045 - val_loss: 2.3624
# Epoch 3/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.6458 - val_loss: 2.5587
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Epoch 1/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.1998 - val_loss: 1.1261
# Epoch 2/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.3077 - val_loss: 1.7177
# Epoch 3/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.9049 - val_loss: 1.9387
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# Epoch 1/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.8211 - val_loss: 2.0593
# Epoch 2/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.1020 - val_loss: 2.3019
# Epoch 3/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.7336 - val_loss: 2.2856
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Epoch 1/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.9077 - val_loss: 2.4726
# Epoch 2/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 18.2945 - val_loss: 1.3680
# Epoch 3/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 2.1190 - val_loss: 1.4479
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Epoch 1/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.6813 - val_loss: 1.2706
# Epoch 2/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.5967 - val_loss: 1.3538
# Epoch 3/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.5385 - val_loss: 1.5282
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# Epoch 1/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.6142 - val_loss: 1.5352
# Epoch 2/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.6443 - val_loss: 1.6766
# Epoch 3/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.5938 - val_loss: 1.6400
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Epoch 1/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.5780 - val_loss: 1.6980
# Epoch 2/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.7041 - val_loss: 1.9152
# Epoch 3/3
# 2548/2548 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.7986 - val_loss: 1.9981
# ...
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7305 - val_loss: 0.8597
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6841 - val_loss: 0.8355
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6095 - val_loss: 0.7711
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6228 - val_loss: 0.9052
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6591 - val_loss: 1.0715
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1075 - val_loss: 0.9810
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7416 - val_loss: 1.0967
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9852 - val_loss: 1.1346
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0177 - val_loss: 1.2524
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2439 - val_loss: 1.3581
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3481 - val_loss: 1.6262
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.2916 - val_loss: 1.2746
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4597 - val_loss: 1.1132
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2176 - val_loss: 1.2167
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.5595 - val_loss: 1.1156
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2699 - val_loss: 1.0403
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0357 - val_loss: 1.0983
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1858 - val_loss: 1.0716
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0451 - val_loss: 1.1360
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2382 - val_loss: 1.0704
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0549 - val_loss: 1.0986
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0738 - val_loss: 1.2073
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3213 - val_loss: 1.0874
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0775 - val_loss: 1.1124
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1051 - val_loss: 1.1765
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1982 - val_loss: 1.2310
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4281 - val_loss: 1.1536
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2014 - val_loss: 1.3954
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.8577 - val_loss: 1.1865
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3504 - val_loss: 1.1060
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1694 - val_loss: 1.0651
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0981 - val_loss: 1.0643
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0669 - val_loss: 1.0515
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0396 - val_loss: 1.0983
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1326 - val_loss: 1.0652
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0413 - val_loss: 1.1218
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1530 - val_loss: 1.1022
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# Epoch 1/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0868 - val_loss: 1.1600
# Epoch 2/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1917 - val_loss: 1.2096
# Epoch 3/3
# 189/189 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3159 - val_loss: 1.1654
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1821 - val_loss: 1.2313
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3454 - val_loss: 1.2349
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3701 - val_loss: 1.2436
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3922 - val_loss: 1.1993
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2438 - val_loss: 1.2680
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.5230 - val_loss: 1.1002
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1319 - val_loss: 1.0611
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0253 - val_loss: 1.0722
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0438 - val_loss: 1.0813
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0164 - val_loss: 1.1732
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.1896 - val_loss: 1.1746
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2543 - val_loss: 1.1346
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0861 - val_loss: 1.2244
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3464 - val_loss: 1.2027
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.2017 - val_loss: 1.0171
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3091 - val_loss: 0.8996
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8740 - val_loss: 0.8247
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6615 - val_loss: 0.7866
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5033 - val_loss: 0.8166
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5671 - val_loss: 0.8181
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5756 - val_loss: 1.0266
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0288 - val_loss: 1.2251
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4049 - val_loss: 1.1076
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0366 - val_loss: 1.0433
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8526 - val_loss: 0.9987
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8657 - val_loss: 1.2311
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4384 - val_loss: 1.0935
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9856 - val_loss: 1.0953
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9931 - val_loss: 1.1047
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9308 - val_loss: 1.4554
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.9314 - val_loss: 1.2901
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3930 - val_loss: 1.2909
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.4846 - val_loss: 0.9833
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3476 - val_loss: 0.9941
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8572 - val_loss: 0.8982
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.6672 - val_loss: 0.7999
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5597 - val_loss: 0.7829
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.5376 - val_loss: 0.9177
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7559 - val_loss: 1.2029
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.3977 - val_loss: 1.0595
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0346 - val_loss: 0.9900
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7344 - val_loss: 1.0304
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.7930 - val_loss: 1.0575
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.8921 - val_loss: 1.0862
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.9038 - val_loss: 1.2149
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.0895 - val_loss: 1.5429
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.2166 - val_loss: 1.3961
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2.6972 - val_loss: 1.2193
#   1/114 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 trainLSTM(modelLSTM, X_train, y_train, X_vali, y_vali, X_test)
#
# Cell In[79], line 7, in trainLSTM(modelLSTM, X_train, y_train, X_vali, y_vali, X_test)
#       5 for i in range(0, 25):
#       6     historyLSTM = modelLSTM.fit(X_train, y_train, epochs=e, batch_size=b, validation_data=(X_vali, y_vali), shuffle=False)
# ----> 7     y_predLSTM = modelLSTM.predict(X_test)
#       8     valor = eval(rpr_prep(df_test), y_aux_prep(y_predLSTM))
#       9     if valor < mejor_valor and valor < 1.0:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py:512, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     510 callbacks.on_predict_batch_begin(step)
#     511 data = get_data(iterator)
# --> 512 batch_outputs = self.predict_function(data)
#     513 outputs = append_to_outputs(batch_outputs, outputs)
#     514 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
